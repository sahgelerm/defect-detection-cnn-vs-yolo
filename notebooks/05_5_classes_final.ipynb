# %%
## https://drive.google.com/file/d/1BIKABqzZ3QaB2AE2BZPOyQwwFVh7ysgQ/view?usp=sharing  vozd_puz
## https://drive.google.com/file/d/1Q2MZQFDXP_wLRt5PIdxynDvq9ShI6RFL/view?usp=sharing  prigar
## https://drive.google.com/file/d/16dFMGdy-Gp6DbYD6tVQJoBa9oKse4GMx/view?usp=sharing  chern_toch
#https://drive.google.com/file/d/1dxkVP1vv1gFubXAXEBL2zZMptauRNKkp/view?usp=sharing non defects
#https://drive.google.com/file/d/1O7pZlootWDy2iUh8342JJc_S8DjR6_F4/view?usp=sharing nedoliv

# %%
# !pip install --upgrade gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.20.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2025.11.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
import os
import gdown
import zipfile
from google.colab import drive

# Подключаем Google Диск
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Указываем путь к папке, где будут распакованы архивы
IMAGE_PATH = '/content/pref/'

# Создаем папку, если она не существует
if not os.path.exists(IMAGE_PATH):
    os.makedirs(IMAGE_PATH)

# Список ссылок на архивы и соответствующие имена папок
urls = [
    ('https://drive.google.com/uc?id=16dFMGdy-Gp6DbYD6tVQJoBa9oKse4GMx', 'chern_toch'),
    ('https://drive.google.com/uc?id=1BIKABqzZ3QaB2AE2BZPOyQwwFVh7ysgQ', 'vozd_puz'),
    ('https://drive.google.com/uc?id=1O7pZlootWDy2iUh8342JJc_S8DjR6_F4', 'nedoliv'),
    ('https://drive.google.com/uc?id=1dxkVP1vv1gFubXAXEBL2zZMptauRNKkp', 'non defects'),
    ('https://drive.google.com/uc?id=1Q2MZQFDXP_wLRt5PIdxynDvq9ShI6RFL', 'prigar')
]

# Загрузка и распаковка архивов
for url, folder_name in urls:
    # Создаем папку для каждого архива
    folder_path = os.path.join(IMAGE_PATH, folder_name)
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    # Получаем имя файла из URL
    output = os.path.join(folder_path, folder_name + '.zip')

    # Загружаем архив
    gdown.download(url, output, quiet=False)

    # Распаковываем архив
    with zipfile.ZipFile(output, 'r') as zip_ref:
        zip_ref.extractall(folder_path)

# Проверяем содержимое папки
print(os.listdir(IMAGE_PATH))
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=16dFMGdy-Gp6DbYD6tVQJoBa9oKse4GMx
# From (redirected): https://drive.google.com/uc?id=16dFMGdy-Gp6DbYD6tVQJoBa9oKse4GMx&confirm=t&uuid=7ac1b0e7-33e1-43bb-a0d7-673c12668528
# To: /content/pref/chern_toch/chern_toch.zip
# 100%|██████████| 1.03G/1.03G [00:16<00:00, 62.2MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1BIKABqzZ3QaB2AE2BZPOyQwwFVh7ysgQ
# From (redirected): https://drive.google.com/uc?id=1BIKABqzZ3QaB2AE2BZPOyQwwFVh7ysgQ&confirm=t&uuid=91ecbb27-5383-4d40-bde5-a5bca320720f
# To: /content/pref/vozd_puz/vozd_puz.zip
# 100%|██████████| 1.23G/1.23G [00:11<00:00, 105MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1O7pZlootWDy2iUh8342JJc_S8DjR6_F4
# From (redirected): https://drive.google.com/uc?id=1O7pZlootWDy2iUh8342JJc_S8DjR6_F4&confirm=t&uuid=c13b6a00-e5f6-4fc8-941e-e3dfdefe4fbe
# To: /content/pref/nedoliv/nedoliv.zip
# 100%|██████████| 762M/762M [00:10<00:00, 74.2MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1dxkVP1vv1gFubXAXEBL2zZMptauRNKkp
# From (redirected): https://drive.google.com/uc?id=1dxkVP1vv1gFubXAXEBL2zZMptauRNKkp&confirm=t&uuid=59f6d712-7d26-48b1-98d1-0b5964a1b84b
# To: /content/pref/non defects/non defects.zip
# 100%|██████████| 1.07G/1.07G [00:17<00:00, 61.6MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1Q2MZQFDXP_wLRt5PIdxynDvq9ShI6RFL
# From (redirected): https://drive.google.com/uc?id=1Q2MZQFDXP_wLRt5PIdxynDvq9ShI6RFL&confirm=t&uuid=02d4d922-8861-4658-8dc6-3a1005507cd9
# To: /content/pref/prigar/prigar.zip
# 100%|██████████| 1.08G/1.08G [00:14<00:00, 76.5MB/s]
# ['prigar', 'non defects', 'chern_toch', 'nedoliv', 'vozd_puz']

# %%
# методы для отрисовки изображений
from PIL import Image

# Для отрисовки графиков
import matplotlib.pyplot as plt

# Для генерации случайных чисел
import random

# Библиотека работы с массивами
import numpy as np

# для разделения выборок
from sklearn.model_selection import train_test_split

# для создания сети
from tensorflow.keras.models import Sequential

# для создания слоев
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization

# для работы с изображениями
from tensorflow.keras.preprocessing import image

# оптимизатор
from tensorflow.keras.optimizers import Adam

# модуль для отсчета времени
import time

# %%
# Указываем пути к файлам
files_to_delete = [
    '/content/pref/chern_toch/chern_toch.zip',
    '/content/pref/vozd_puz/vozd_puz.zip',
    '/content/pref/nedoliv/nedoliv.zip',
    '/content/pref/non defects/non defects.zip',
    '/content/pref/prigar/prigar.zip'
]

# Удаляем файлы
for file_path in files_to_delete:
    try:
        os.remove(file_path)
        print(f'Файл {file_path} успешно удален.')
    except FileNotFoundError:
        print(f'Файл {file_path} не найден.')
    except Exception as e:
        print(f'Ошибка при удалении файла {file_path}: {e}')
# Out:
# Файл /content/pref/chern_toch/chern_toch.zip успешно удален.
# Файл /content/pref/vozd_puz/vozd_puz.zip успешно удален.
# Файл /content/pref/nedoliv/nedoliv.zip успешно удален.
# Файл /content/pref/non defects/non defects.zip успешно удален.
# Файл /content/pref/prigar/prigar.zip успешно удален.

# %%
# Получение списка папок, находящемуся по адресу в скобках
os.listdir(IMAGE_PATH)
# Out:
# ['prigar', 'non defects', 'chern_toch', 'nedoliv', 'vozd_puz']

# %%
# Определение списка имен классов
CLASS_LIST = sorted(os.listdir(IMAGE_PATH))

# Определение количества классов
CLASS_COUNT = len(CLASS_LIST)

# Проверка результата
print(f'Количество классов: {CLASS_COUNT}, метки классов: {CLASS_LIST}')
# Out:
# Количество классов: 5, метки классов: ['chern_toch', 'nedoliv', 'non defects', 'prigar', 'vozd_puz']

# %%
# Получения списка файлов для каждого класса

for cls in CLASS_LIST:
    print(cls, ':', os.listdir(f'{IMAGE_PATH}{cls}/'))
# Out:
# chern_toch : ['aug_0_3023.bmp', 'aug_0_6049.bmp', 'aug_0_9223.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-133627-297-445502173966.BMP', 'aug_0_4531.bmp', 'aug_0_434.bmp', 'aug_0_9771.bmp', 'aug_0_7134.bmp', 'aug_0_5198.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-133223-681-443066018390.BMP', 'aug_0_7438.bmp', 'aug_0_1703.bmp', 'aug_0_6012.bmp', 'aug_0_757.bmp', 'aug_0_740.bmp', 'aug_0_6831.bmp', 'aug_0_8501.bmp', 'aug_0_5527.bmp', 'aug_0_9610.bmp', 'aug_0_5671.bmp', 'aug_0_2348.bmp', 'aug_0_2732.bmp', 'aug_0_7013.bmp', 'aug_0_1079.bmp', 'aug_0_7666.bmp', 'aug_0_9055.bmp', 'aug_0_8099.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-
bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-124452-638-414555578503.BMP', 'aug_0_4128.bmp', 'aug_0_3285.bmp', 'aug_0_448.bmp', 'aug_0_3829.bmp', 'aug_0_2027.bmp', 'aug_0_6431.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-124956-324-417592439948.BMP', 'aug_0_9145.bmp', 'aug_0_9275.bmp', 'aug_0_4580.bmp', 'HT-SUA501GC-T1V-C-Snapshot-2025082 ...

# %%
# Создание заготовки для изображений всех классов
fig, axs = plt.subplots(1, CLASS_COUNT, figsize=(10, 5))

# Для всех номеров классов:
for i in range(CLASS_COUNT):

    # Формирование пути к папке содержимого класса
    car_path = f'{IMAGE_PATH}{CLASS_LIST[i]}/'

    # Выбор случайного фото из i-го класса
    img_path = car_path + random.choice(os.listdir(car_path))

    # Отображение фотографии (подробнее будет объяснено далее)
    axs[i].set_title(CLASS_LIST[i])
    axs[i].imshow(Image.open(img_path))
    axs[i].axis('off')

# Отрисовка всего полотна
plt.show()

# %%
data_files = []                           # Cписок путей к файлам картинок
data_labels = []                          # Список меток классов, соответствующих файлам

for class_label in range(CLASS_COUNT):    # Для всех классов по порядку номеров (их меток)
    class_name = CLASS_LIST[class_label]  # Выборка имени класса из списка имен
    class_path = IMAGE_PATH + class_name  # Формирование полного пути к папке с изображениями класса
    class_files = os.listdir(class_path)  # Получение списка имен файлов с изображениями текущего класса
    print(f'Размер класса {class_name} составляет {len(class_files)} фото')

    # Добавление к общему списку всех файлов класса с добавлением родительского пути
    data_files += [f'{class_path}/{file_name}' for file_name in class_files]

    # Добавление к общему списку меток текущего класса - их ровно столько, сколько файлов в классе
    data_labels += [class_label] * len(class_files)

print()
print('Общий размер базы для обучения:', len(data_labels))
# Out:
# Размер класса chern_toch составляет 859 фото
# Размер класса nedoliv составляет 970 фото
# Размер класса non defects составляет 1212 фото
# Размер класса prigar составляет 914 фото
# Размер класса vozd_puz составляет 1024 фото
#
# Общий размер базы для обучения: 4979

# %%
# Задание единых размеров изображений
IMG_WIDTH = 128                           # Ширина изображения
IMG_HEIGHT = 64                           # Высота изображения

# %%
# перевод изображений в тензоры
data_images = []                          # Пустой список для данных изображений

for file_name in data_files:
    # Открытие и смена размера изображения
    img = Image.open(file_name).resize((IMG_WIDTH, IMG_HEIGHT))
    img_np = np.array(img)                # Перевод в numpy-массив
    data_images.append(img_np)            # Добавление изображения в виде numpy-массива к общему списку

x_data = np.array(data_images)            # Перевод общего списка изображений в numpy-массив
y_data = np.array(data_labels)            # Перевод общего списка меток класса в numpy-массив

print(f'В массив собрано {len(data_images)} фотографий следующей формы: {img_np.shape}')
print(f'Общий массив данных изображений следующей формы: {x_data.shape}')
print(f'Общий массив меток классов следующей формы: {y_data.shape}')
# Out:
# В массив собрано 4979 фотографий следующей формы: (64, 128, 3)
# Общий массив данных изображений следующей формы: (4979, 64, 128, 3)
# Общий массив меток классов следующей формы: (4979,)

# %%
# вывод первого изображения (трехмерный тензор)
x_data[0]
# Out:
# array([[[ 77, 123, 179],
#         [ 77, 122, 179],
#         [ 77, 122, 179],
#         ...,
#         [ 54, 103, 162],
#         [ 58, 100, 161],
#         [ 54,  97, 148]],
#
#        [[ 78, 124, 186],
#         [ 78, 124, 186],
#         [ 78, 124, 185],
#         ...,
#         [ 54, 103, 163],
#         [ 59,  99, 159],
#         [ 50,  97, 145]],
#
#        [[ 79, 123, 185],
#         [ 78, 123, 185],
#         [ 78, 123, 186],
#         ...,
#         [ 55, 101, 157],
#         [ 57,  99, 153],
#         [ 54,  99, 150]],
#
#        ...,
#
#        [[ 87, 139, 199],
#         [ 86, 140, 216],
#         [ 88, 140, 205],
#         ...,
#         [ 55,  91, 140],
#         [ 55,  91, 140],
#         [ 54,  91, 140]],
#
#        [[ 88, 139, 206],
#         [ 86, 140, 213],
#         [ 87, 140, 205],
#         ...,
#         [ 53,  89, 135],
#         [ 53,  89, 136],
#         [ 54,  89, 135]],
#
#        [[ 87, 140, 214],
#         [ 87, 140, 209],
#         [ 86, 138, 204],
#         ...,
#         [ 53,  93, 141],
#         [ 53,  93, 141],
#         [ 53,  93, 140]]], dtype=uint8)

# %%
# Создание модели последовательной архитектуры
model = Sequential()

# %%
# Первый сверточный блок
model.add(Conv2D(256, (3, 3), name='First_C', padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)))  # (64,128,3) --> (64,128,256) меняется кол-во фильтров
model.add(BatchNormalization(name='First_B'))  # (64,128,256) --> (64,128,256) нет изменений
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Второй сверточный блок
model.add(Conv2D(256, (3, 3), name='Second_C', padding='same', activation='relu'))  # (64,128,256) --> (64,128,256) нет изменений
model.add(MaxPooling2D(pool_size=(3, 3), name='Second_M'))  # сжимает размер в три раза, с потерей, т.к. padding='valid', глубина не изм. (64,128,256) --> (21,42,256)

# %%
# Третий сверточный блок
model.add(Conv2D(256, (3, 3), name='Third_C', padding='same', activation='relu'))  # (21,42,256) --> (21,42,256) нет изменений
model.add(BatchNormalization(name='Third_B'))  # (21,42,256) --> (21,42,256) нет изменений
model.add(Dropout(0.2, name='Third_D'))  # (21,42,256) --> (21,42,256) нет изменений

# %%
# Четвертый сверточный блок
model.add(Conv2D(256, (3, 3), name='Fourth_F_Unique', padding='same', activation='relu'))  # (21,42,256) --> (21,42,256) нет изменений
model.add(MaxPooling2D(pool_size=(3, 3), name='Fourth_M_Unique'))  # сжимает размер в три раза, хотя padding='valid', потерь нет, т.к. делится кратно, глубина не изм. (21,42,256) --> (7,14,256)
model.add(Dropout(0.2, name='Fourth_D_Unique'))  # (7,14,256) --> (7,14,256) нет изменений

# %%
# Пятый сверточный блок
model.add(Conv2D(512, (3, 3), name='Fifth_D', padding='same', activation='relu'))  # (7,14,256) --> (7,14,512) меняется количество фильтров
model.add(BatchNormalization(name='Fifth_B'))  # (7,14,512) --> (7,14,512) нет изменений

# %%
# Шестой сверточный блок
model.add(Conv2D(1024, (3, 3), name='Sixth_C', padding='same', activation='relu'))  # (7,14,1024) --> (7,14,1024) меняется кол-во фильтров
model.add(MaxPooling2D(pool_size=(3, 3), name='Sixth_M'))  # сжимает размер в три раза, с потерей, т.к. padding='valid', глубина не изм. (7,14,1024) --> (2,4,1024)
model.add(Dropout(0.2, name='Sixth_D'))  # (2,4,1024) --> (2,4,1024) нет изменений

# %%
# Блок классификации
model.add(Flatten(name='Class_11'))  # слой преобразования многомерных данных в одномерные (2,4,1024) --> (2*4*1024) --> (8192)
model.add(Dense(2048, activation='relu', name='Class_12'))  # полносвязный слой, меняется кол-во нейронов (8192) --> (2048)
# model.add(Dense(4096, activation='relu', name='Class_3'))  # полносвязный слой, меняется кол-во нейронов (2048) --> (4096)
model.add(Dense(CLASS_COUNT, activation='softmax', name='Class_13'))  # выходной полносвязный слой, кол-во нейронов = количество классов (4096) --> (3)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ First_C (Conv2D)                │ (None, 64, 128, 256)   │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ First_B (BatchNormalization)    │ (None, 64, 128, 256)   │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Second_C (Conv2D)               │ (None, 64, 128, 256)   │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Second_M (MaxPooling2D)         │ (None, 21, 42, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Third_C (Conv2D)                │ (None, 21, 42, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Third_B (BatchNormalization)    │ (None, 21, 42, 256)    │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Third_D (Dropout)               │ (None, 21, 42, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Fourth_F_Unique (Conv2D)        │ (None, 21, 42, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Fourth_M_Unique (MaxPooling2D)  │ (None, 7, 14, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Fourth_D_Unique (Dropout)       │ (None, 7, 14, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Fifth_D (Conv2D)                │ (None, 7, 14, 512)     │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Fifth_B (BatchNormalization)    │ (None, 7, 14, 512)     │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Sixth_C (Conv2D)                │ (None, 7, 14, 1024)    │     4,719,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Sixth_M (MaxPooling2D)          │ (None, 2, 4, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Sixth_D (Dropout)               │ (None, 2, 4, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Class_11 (Flatten)              │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Class_12 (Dense)                │ (None, 2048)           │    16,779,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Class_13 (Dense)                │ (None, 5)              │        10,245 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,470,789 (93.35 MB)
#  Trainable params: 24,468,741 (93.34 MB)
#  Non-trainable params: 2,048 (8.00 KB)

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# Компиляция модели
model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])

# %%
# Разделение данных на обучающую и тестовую выборки
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

# %%
# Определение колбэков
model_checkpoint = ModelCheckpoint(filepath='model_best.h5', monitor='val_loss', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.6, patience=2, verbose=1)

# %%
# Обучение модели и сохранение истории
history = model.fit(x_train,  # Обучающая выборка
                    y_train,  # Метки обучающей выборки
                    validation_data=(x_test, y_test),  # Тестовая выборка для валидации
                    shuffle=True,
                    batch_size=64,
                    epochs=30,
                    verbose=1,
                    callbacks=[model_checkpoint, reduce_lr])  # Добавление колбэков
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - accuracy: 0.4657 - loss: 2.5419
# Epoch 1: val_loss improved from inf to 8.11296, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 97s 913ms/step - accuracy: 0.4676 - loss: 2.5238 - val_accuracy: 0.1968 - val_loss: 8.1130 - learning_rate: 1.0000e-04
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.7556 - loss: 0.5437
# Epoch 2: val_loss improved from 8.11296 to 1.05730, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 400ms/step - accuracy: 0.7560 - loss: 0.5430 - val_accuracy: 0.5552 - val_loss: 1.0573 - learning_rate: 1.0000e-04
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.8325 - loss: 0.4055
# Epoch 3: val_loss did not improve from 1.05730
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 392ms/step - accuracy: 0.8323 - loss: 0.4056 - val_accuracy: 0.5060 - val_loss: 1.4830 - learning_rate: 1.0000e-04
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.8642 - loss: 0.3188
# Epoch 4: val_loss did not improve from 1.05730
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 5.999999848427251e-05.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 398ms/step - accuracy: 0.8643 - loss: 0.3186 - val_accuracy: 0.6777 - val_loss: 1.1683 - learning_rate: 1.0000e-04
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.8769 - loss: 0.2854
# Epoch 5: val_loss did not improve from 1.05730
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 402ms/step - accuracy: 0.8771 - loss: 0.2852 - val_accuracy: 0.4880 - val_loss: 1.8406 - learning_rate: 6.0000e-05
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.9165 - loss: 0.1981
# Epoch 6: val_loss did not improve from 1.05730
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 3.599999909056351e-05.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 399ms/step - accuracy: 0.9165 - loss: 0.1980 - val_accuracy: 0.5472 - val_loss: 1.5577 - learning_rate: 6.0000e-05
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9415 - loss: 0.1519
# Epoch 7: val_loss did not improve from 1.05730
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 41s 400ms/step - accuracy: 0.9414 - loss: 0.1519 - val_accuracy: 0.6576 - val_loss: 1.2261 - learning_rate: 3.6000e-05
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step - accuracy: 0.9590 - loss: 0.1275
# Epoch 8: val_loss improved from 1.05730 to 0.92793, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 32s 513ms/step - accuracy: 0.9590 - loss: 0.1276 - val_accuracy: 0.7108 - val_loss: 0.9279 - learning_rate: 3.6000e-05
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9490 - loss: 0.1277
# Epoch 9: val_loss improved from 0.92793 to 0.62761, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 26s 414ms/step - accuracy: 0.9491 - loss: 0.1275 - val_accuracy: 0.7691 - val_loss: 0.6276 - learning_rate: 3.6000e-05
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9696 - loss: 0.0907
# Epoch 10: val_loss improved from 0.62761 to 0.35059, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 26s 416ms/step - accuracy: 0.9694 - loss: 0.0909 - val_accuracy: 0.8665 - val_loss: 0.3506 - learning_rate: 3.6000e-05
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.9624 - loss: 0.0928
# Epoch 11: val_loss did not improve from 0.35059
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 400ms/step - accuracy: 0.9623 - loss: 0.0930 - val_accuracy: 0.6837 - val_loss: 1.2233 - learning_rate: 3.6000e-05
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9362 - loss: 0.1445
# Epoch 12: val_loss did not improve from 0.35059
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.1599998581223188e-05.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 398ms/step - accuracy: 0.9365 - loss: 0.1440 - val_accuracy: 0.7962 - val_loss: 0.5872 - learning_rate: 3.6000e-05
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9714 - loss: 0.0810
# Epoch 13: val_loss did not improve from 0.35059
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 397ms/step - accuracy: 0.9715 - loss: 0.0808 - val_accuracy: 0.8434 - val_loss: 0.3795 - learning_rate: 2.1600e-05
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9803 - loss: 0.0577
# Epoch 14: val_loss did not improve from 0.35059
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.2959999367012642e-05.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 398ms/step - accuracy: 0.9803 - loss: 0.0577 - val_accuracy: 0.8323 - val_loss: 0.4529 - learning_rate: 2.1600e-05
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9852 - loss: 0.0463
# Epoch 15: val_loss improved from 0.35059 to 0.32949, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 26s 417ms/step - accuracy: 0.9852 - loss: 0.0463 - val_accuracy: 0.8805 - val_loss: 0.3295 - learning_rate: 1.2960e-05
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9875 - loss: 0.0479
# Epoch 16: val_loss improved from 0.32949 to 0.22447, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 26s 416ms/step - accuracy: 0.9876 - loss: 0.0479 - val_accuracy: 0.9106 - val_loss: 0.2245 - learning_rate: 1.2960e-05
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9856 - loss: 0.0451
# Epoch 17: val_loss did not improve from 0.22447
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 398ms/step - accuracy: 0.9856 - loss: 0.0451 - val_accuracy: 0.9046 - val_loss: 0.2379 - learning_rate: 1.2960e-05
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9896 - loss: 0.0382
# Epoch 18: val_loss improved from 0.22447 to 0.19601, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 26s 415ms/step - accuracy: 0.9896 - loss: 0.0382 - val_accuracy: 0.9207 - val_loss: 0.1960 - learning_rate: 1.2960e-05
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9893 - loss: 0.0401
# Epoch 19: val_loss did not improve from 0.19601
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 398ms/step - accuracy: 0.9893 - loss: 0.0401 - val_accuracy: 0.9036 - val_loss: 0.2416 - learning_rate: 1.2960e-05
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9861 - loss: 0.0374
# Epoch 20: val_loss improved from 0.19601 to 0.17340, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 26s 415ms/step - accuracy: 0.9861 - loss: 0.0375 - val_accuracy: 0.9287 - val_loss: 0.1734 - learning_rate: 1.2960e-05
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9916 - loss: 0.0384
# Epoch 21: val_loss did not improve from 0.17340
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 398ms/step - accuracy: 0.9916 - loss: 0.0384 - val_accuracy: 0.8876 - val_loss: 0.2931 - learning_rate: 1.2960e-05
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9919 - loss: 0.0340
# Epoch 22: val_loss did not improve from 0.17340
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 7.775999620207585e-06.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 398ms/step - accuracy: 0.9919 - loss: 0.0339 - val_accuracy: 0.8936 - val_loss: 0.2890 - learning_rate: 1.2960e-05
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9908 - loss: 0.0307
# Epoch 23: val_loss did not improve from 0.17340
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 398ms/step - accuracy: 0.9909 - loss: 0.0306 - val_accuracy: 0.9307 - val_loss: 0.1921 - learning_rate: 7.7760e-06
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9920 - loss: 0.0262
# Epoch 24: val_loss did not improve from 0.17340
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 4.665599772124551e-06.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 397ms/step - accuracy: 0.9920 - loss: 0.0262 - val_accuracy: 0.9106 - val_loss: 0.2176 - learning_rate: 7.7760e-06
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9927 - loss: 0.0242
# Epoch 25: val_loss did not improve from 0.17340
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 397ms/step - accuracy: 0.9927 - loss: 0.0242 - val_accuracy: 0.8996 - val_loss: 0.2532 - learning_rate: 4.6656e-06
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9957 - loss: 0.0203
# Epoch 26: val_loss did not improve from 0.17340
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 2.7993597541353666e-06.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 398ms/step - accuracy: 0.9957 - loss: 0.0204 - val_accuracy: 0.9237 - val_loss: 0.1988 - learning_rate: 4.6656e-06
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9952 - loss: 0.0201
# Epoch 27: val_loss improved from 0.17340 to 0.14836, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 26s 413ms/step - accuracy: 0.9952 - loss: 0.0201 - val_accuracy: 0.9438 - val_loss: 0.1484 - learning_rate: 2.7994e-06
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9944 - loss: 0.0211
# Epoch 28: val_loss did not improve from 0.14836
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 398ms/step - accuracy: 0.9944 - loss: 0.0212 - val_accuracy: 0.9227 - val_loss: 0.1916 - learning_rate: 2.7994e-06
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9952 - loss: 0.0215
# Epoch 29: val_loss did not improve from 0.14836
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.6796157979115377e-06.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 397ms/step - accuracy: 0.9952 - loss: 0.0214 - val_accuracy: 0.9307 - val_loss: 0.1865 - learning_rate: 2.7994e-06
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9956 - loss: 0.0236
# Epoch 30: val_loss did not improve from 0.14836
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 398ms/step - accuracy: 0.9956 - loss: 0.0235 - val_accuracy: 0.9227 - val_loss: 0.1970 - learning_rate: 1.6796e-06

# %%
scores = model.evaluate(x_data,
                        y_data,
                        verbose=1
                        )
print('Процент верных ответов на тестовых данных:', round(scores[1],2) * 100, '%')
# Out:
# 156/156 ━━━━━━━━━━━━━━━━━━━━ 23s 105ms/step - accuracy: 0.9711 - loss: 0.0856
# Процент верных ответов на тестовых данных: 96.0 %

# %%
# Оценка модели на тестовой выборке
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=1)

print(f'Тестовая точность: {test_accuracy:.4f}')
print(f'Тестовая потеря: {test_loss:.4f}')
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.9330 - loss: 0.1644
# Тестовая точность: 0.9227
# Тестовая потеря: 0.1970

# %%
# Визуализация процесса обучения
plt.figure(figsize=(12, 4))

# График потерь
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Обучающие потери')
plt.plot(history.history['val_loss'], label='Валидационные потери')
plt.title('Потери модели')
plt.xlabel('Эпохи')
plt.ylabel('Потери')
plt.legend()

# График точности
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Обучающая точность')
plt.plot(history.history['val_accuracy'], label='Валидационная точность')
plt.title('Точность модели')
plt.xlabel('Эпохи')
plt.ylabel('Точность')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Получение предсказаний
predictions = model.predict(x_test)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 95ms/step

# %%
# Определение класса с максимальной вероятностью для каждого изображения
predicted_classes = np.argmax(predictions, axis=1)

# %%
# Определение точности для каждого класса
class_labels = ['chern_toch', 'vozd_puz', 'nedoliv', 'non defects', 'prigar']
accuracies = {}

for cls in range(len(class_labels)):
    # Получаем индексы изображений, принадлежащих текущему классу
    class_indices = np.where(y_test == cls)[0]
    if len(class_indices) > 0:
        # Предсказанные классы для текущего класса
        predicted_for_class = predicted_classes[class_indices]
        # Вычисляем точность
        accuracy = np.sum(predicted_for_class == cls) / len(class_indices)
        accuracies[class_labels[cls]] = accuracy

# Вывод точности для каждого класса
for label, accuracy in accuracies.items():
    print(f'Точность для класса "{label}": {accuracy:.2f}')
# Out:
# Точность для класса "chern_toch": 0.97
# Точность для класса "vozd_puz": 0.87
# Точность для класса "nedoliv": 0.99
# Точность для класса "non defects": 0.77
# Точность для класса "prigar": 1.00

# %%
# Выбор одного изображения из каждого класса
unique_classes = np.unique(predicted_classes)
images_per_class = []
for cls in unique_classes:
    class_indices = np.where(predicted_classes == cls)[0]
    if len(class_indices) > 0:
        images_per_class.append(x_test[class_indices[0]])

# %%
# Визуализация выбранных изображений
plt.figure(figsize=(12, 8))
for i, img in enumerate(images_per_class):
    plt.subplot(2, 2, i + 1)
    plt.imshow(img)
    plt.title(f'Класс: {class_labels[i]}')
    plt.axis('off')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1858509771.py in <cell line: 0>()
#       2 plt.figure(figsize=(12, 8))
#       3 for i, img in enumerate(images_per_class):
# ----> 4     plt.subplot(2, 2, i + 1)
#       5     plt.imshow(img)
#       6     plt.title(f'Класс: {class_labels[i]}')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1548
#    1549     # First, search for an existing subplot with a matching spec.
# -> 1550     key = SubplotSpec._from_subplot_args(fig, args)
#    1551
#    1552     for ax in fig.axes:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     587         else:
#     588             if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 589                 raise ValueError(
#     590                     f"num must be an integer with 1 <= num <= {rows*cols}, "
#     591                     f"not {num!r}"
#
# ValueError: num must be an integer with 1 <= num <= 4, not 5

# %%
from keras.models import load_model

# %%
# После завершения обучения модели
model.save('my_model.keras')

# %%
# Указываем имя папки для сохранения модели
folder_name = 'Best GA models_2'

# Проверяем, существует ли папка, если нет - создаем
if not os.path.exists('/content/drive/MyDrive/' + folder_name):
    os.makedirs('/content/drive/MyDrive/' + folder_name)

# Сохраняем модель
model.save('/content/drive/MyDrive/{}/my_model.keras'.format(folder_name))

# %%
# https://drive.google.com/file/d/119mY0sL0IMFruc-7BlL5Bj3FJ03dizVN/view?usp=sharing ссылка на модель_1

# %%
# https://drive.google.com/drive/folders/1UoVPMOBCuFjAz1ESZup-E84AoSw9zaX6?usp=sharing ссылка модель_2
