# %%
# https://drive.google.com/file/d/1SowPR9HaH9z9yBCqPxMLMb-HdTl3TnFv/view?usp=sharing возд пуз

# %%
import os
import gdown
import zipfile
from google.colab import drive

# Подключаем Google Диск
drive.mount('/content/drive')

# Указываем путь к папке, где будут распакованы архивы
IMAGE_PATH = '/content/pref/'

# Создаем папку, если она не существует
if not os.path.exists(IMAGE_PATH):
    os.makedirs(IMAGE_PATH)

# Список ссылок на архивы и соответствующие имена папок
urls = [
    ('https://drive.google.com/uc?id=1SowPR9HaH9z9yBCqPxMLMb-HdTl3TnFv', 'vozd_puz'),
    ('https://drive.google.com/uc?id=1zG83stcXAXF4LYkurayhT4Om8Us8P5UT', 'prigar'),
    ('https://drive.google.com/uc?id=1UPEkUIxxm1J_mFpfUs1_4asJ-PBbl60L', 'chern_toch')
]

# Загрузка и распаковка архивов
for url, folder_name in urls:
    # Создаем папку для каждого архива
    folder_path = os.path.join(IMAGE_PATH, folder_name)
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    # Получаем имя файла из URL
    output = os.path.join(folder_path, folder_name + '.zip')

    # Загружаем архив
    gdown.download(url, output, quiet=False)

    # Распаковываем архив
    with zipfile.ZipFile(output, 'r') as zip_ref:
        zip_ref.extractall(folder_path)

# Проверяем содержимое папки
print(os.listdir(IMAGE_PATH))
# Out:
# Mounted at /content/drive
# Downloading...
# From (original): https://drive.google.com/uc?id=1SowPR9HaH9z9yBCqPxMLMb-HdTl3TnFv
# From (redirected): https://drive.google.com/uc?id=1SowPR9HaH9z9yBCqPxMLMb-HdTl3TnFv&confirm=t&uuid=da9cd5b0-c6ee-45df-8a18-f7671543e498
# To: /content/pref/vozd_puz/vozd_puz.zip
# 100%|██████████| 1.23G/1.23G [00:10<00:00, 115MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1zG83stcXAXF4LYkurayhT4Om8Us8P5UT
# From (redirected): https://drive.google.com/uc?id=1zG83stcXAXF4LYkurayhT4Om8Us8P5UT&confirm=t&uuid=d60a820a-8706-497d-894a-85e946c7112c
# To: /content/pref/prigar/prigar.zip
# 100%|██████████| 1.08G/1.08G [00:18<00:00, 58.3MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1UPEkUIxxm1J_mFpfUs1_4asJ-PBbl60L
# From (redirected): https://drive.google.com/uc?id=1UPEkUIxxm1J_mFpfUs1_4asJ-PBbl60L&confirm=t&uuid=2a305cb9-bcc9-44fa-8b89-49b1e5cc71e5
# To: /content/pref/chern_toch/chern_toch.zip
# 100%|██████████| 1.03G/1.03G [00:17<00:00, 58.0MB/s]
# ['chern_toch', 'prigar', 'vozd_puz']

# %%
# методы для отрисовки изображений
from PIL import Image

# Для отрисовки графиков
import matplotlib.pyplot as plt

# Для генерации случайных чисел
import random

# Библиотека работы с массивами
import numpy as np

# для разделения выборок
from sklearn.model_selection import train_test_split

# для создания сети
from tensorflow.keras.models import Sequential

# для создания слоев
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization

# для работы с изображениями
from tensorflow.keras.preprocessing import image

# оптимизатор
from tensorflow.keras.optimizers import Adam

# модуль для отсчета времени
import time

# %%
# Указываем пути к файлам
files_to_delete = [
    '/content/pref/vozd_puz/vozd_puz.zip',
    '/content/pref/prigar/prigar.zip',
    '/content/pref/chern_toch/chern_toch.zip'
]

# Удаляем файлы
for file_path in files_to_delete:
    try:
        os.remove(file_path)
        print(f'Файл {file_path} успешно удален.')
    except FileNotFoundError:
        print(f'Файл {file_path} не найден.')
    except Exception as e:
        print(f'Ошибка при удалении файла {file_path}: {e}')
# Out:
# Файл /content/pref/vozd_puz/vozd_puz.zip успешно удален.
# Файл /content/pref/prigar/prigar.zip успешно удален.
# Файл /content/pref/chern_toch/chern_toch.zip успешно удален.

# %%
# Получение списка папок, находящемуся по адресу в скобках
os.listdir(IMAGE_PATH)
# Out:
# ['chern_toch', 'prigar', 'vozd_puz']

# %%
# Определение списка имен классов
CLASS_LIST = sorted(os.listdir(IMAGE_PATH))

# Определение количества классов
CLASS_COUNT = len(CLASS_LIST)

# Проверка результата
print(f'Количество классов: {CLASS_COUNT}, метки классов: {CLASS_LIST}')
# Out:
# Количество классов: 3, метки классов: ['chern_toch', 'prigar', 'vozd_puz']

# %%
# Получения списка файлов для каждого класса

for cls in CLASS_LIST:
    print(cls, ':', os.listdir(f'{IMAGE_PATH}{cls}/'))
# Out:
# chern_toch : ['aug_0_9080.bmp', 'aug_0_4758.bmp', 'aug_0_2747.bmp', 'aug_0_2814.bmp', 'aug_0_5191.bmp', 'aug_0_7212.bmp', 'aug_0_7016.bmp', 'aug_0_1746.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-133330-767-443736879935.BMP', 'aug_0_2207.bmp', 'aug_0_9526.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-133218-636-443015569014.BMP', 'aug_0_2253.bmp', 'aug_0_4059.bmp', 'aug_0_3279.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-133107-343-442302643404.BMP', 'aug_0_6628.bmp', 'aug_0_4198.bmp', 'aug_0_8032.bmp', 'aug_0_9094.bmp', 'aug_0_1070.bmp', 'aug_0_8376.bmp', 'aug_0_1577.bmp', 'aug_0_6412.bmp', 'aug_0_4181.bmp', 'aug_0_421.bmp', 'aug_0_8141.bmp', 'aug_0_8556.bmp', 'aug_0_6168.bmp', 'aug_0_2106.bmp', 'aug_0_5447.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-133458-014-444609351673.BMP', 'aug_0_5694.bmp', 'aug_0_1613.bmp', 'aug_0_936.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-133119-521-442424428166.BMP', 'aug_0_4731.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-133707-543-445904641747.BMP', 'aug_0_1997.bmp', 'aug_0_2688.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-133127-519-442504399986.BMP', 'aug_0_6876.bmp', 'aug_0_7604.bmp', 'aug_0_1328.bmp', 'aug_0_7184.bmp', 'aug_0_3144.bmp', 'aug_0_1813.bmp', 'aug_0_7013.bmp', 'aug_0_2491.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-133107-852-442307731322.BMP', 'HT-SUA501GC-T1V-C-Snapshot-20250823-133623-220-445461401675.BMP', 'aug_0_2384.bmp', 'aug_0_6669.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-123654-427-409773476853.BMP', 'aug_0_4291.bmp', 'aug_0_95.bmp', 'aug_0_551.bmp', 'aug_0_7277.bmp', 'aug_0_9191.bmp', 'aug_0_1348.bmp', 'aug_0_6605.bmp', 'aug_0_7864.bmp', 'aug_0_2108.bmp', 'aug_0_648.bmp', 'aug_0_4033.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-133348-041-443909621056.BMP', 'HT-SUA501GC-T1V-C-Snapshot-20250823-133127-197-442501176410.BMP', 'aug_0_7264.bmp', 'aug_0_9138.bmp', 'aug_0_8958.bmp', 'aug_0_5121.bmp', 'aug_0_7881.bmp', 'aug_0_8384.bmp', 'aug_0_3818.bmp', 'aug_0_5352.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-133558-698-445216184618.BMP', 'aug_0_169.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-
bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-124317-601-413605212461.BMP', 'HT-SUA501GC-T1V-C-Snapshot-20250823-124038-548-412014683271.BMP', 'aug_0_3270.bmp', 'aug_0_4356.bmp', 'aug_0_1353.bmp', 'aug_0_497.bmp', 'aug_0_3224.bmp', 'HT-SUA501GC-T1V-C-Snapshot-20250823-124443-811-414467316882 ...

# %%
# Создание заготовки для изображений всех классов
fig, axs = plt.subplots(1, CLASS_COUNT, figsize=(10, 5))

# Для всех номеров классов:
for i in range(CLASS_COUNT):

    # Формирование пути к папке содержимого класса
    car_path = f'{IMAGE_PATH}{CLASS_LIST[i]}/'

    # Выбор случайного фото из i-го класса
    img_path = car_path + random.choice(os.listdir(car_path))

    # Отображение фотографии (подробнее будет объяснено далее)
    axs[i].set_title(CLASS_LIST[i])
    axs[i].imshow(Image.open(img_path))
    axs[i].axis('off')

# Отрисовка всего полотна
plt.show()

# %%
data_files = []                           # Cписок путей к файлам картинок
data_labels = []                          # Список меток классов, соответствующих файлам

for class_label in range(CLASS_COUNT):    # Для всех классов по порядку номеров (их меток)
    class_name = CLASS_LIST[class_label]  # Выборка имени класса из списка имен
    class_path = IMAGE_PATH + class_name  # Формирование полного пути к папке с изображениями класса
    class_files = os.listdir(class_path)  # Получение списка имен файлов с изображениями текущего класса
    print(f'Размер класса {class_name} составляет {len(class_files)} фото')

    # Добавление к общему списку всех файлов класса с добавлением родительского пути
    data_files += [f'{class_path}/{file_name}' for file_name in class_files]

    # Добавление к общему списку меток текущего класса - их ровно столько, сколько файлов в классе
    data_labels += [class_label] * len(class_files)

print()
print('Общий размер базы для обучения:', len(data_labels))
# Out:
# Размер класса chern_toch составляет 870 фото
# Размер класса prigar составляет 911 фото
# Размер класса vozd_puz составляет 1020 фото
#
# Общий размер базы для обучения: 2801

# %%
# Задание единых размеров изображений
IMG_WIDTH = 128                           # Ширина изображения
IMG_HEIGHT = 64                           # Высота изображения

# %%
# перевод изображений в тензоры
data_images = []                          # Пустой список для данных изображений

for file_name in data_files:
    # Открытие и смена размера изображения
    img = Image.open(file_name).resize((IMG_WIDTH, IMG_HEIGHT))
    img_np = np.array(img)                # Перевод в numpy-массив
    data_images.append(img_np)            # Добавление изображения в виде numpy-массива к общему списку

x_data = np.array(data_images)            # Перевод общего списка изображений в numpy-массив
y_data = np.array(data_labels)            # Перевод общего списка меток класса в numpy-массив

print(f'В массив собрано {len(data_images)} фотографий следующей формы: {img_np.shape}')
print(f'Общий массив данных изображений следующей формы: {x_data.shape}')
print(f'Общий массив меток классов следующей формы: {y_data.shape}')
# Out:
# В массив собрано 2801 фотографий следующей формы: (64, 128, 3)
# Общий массив данных изображений следующей формы: (2801, 64, 128, 3)
# Общий массив меток классов следующей формы: (2801,)

# %%
# вывод первого изображения (трехмерный тензор)
x_data[0]
# Out:
# array([[[ 57,  94, 140],
#         [ 57,  94, 140],
#         [ 57,  94, 140],
#         ...,
#         [ 46,  81, 126],
#         [ 45,  81, 126],
#         [ 44,  79, 123]],
#
#        [[ 55,  95, 148],
#         [ 55,  95, 148],
#         [ 55,  95, 148],
#         ...,
#         [ 46,  82, 125],
#         [ 46,  80, 123],
#         [ 45,  79, 122]],
#
#        [[ 57,  96, 145],
#         [ 57,  96, 145],
#         [ 57,  96, 146],
#         ...,
#         [ 45,  81, 128],
#         [ 45,  79, 125],
#         [ 44,  78, 126]],
#
#        ...,
#
#        [[ 74, 117, 181],
#         [ 77, 123, 184],
#         [ 81, 129, 193],
#         ...,
#         [ 54,  88, 122],
#         [ 54,  88, 122],
#         [ 54,  88, 122]],
#
#        [[ 75, 118, 182],
#         [ 77, 123, 185],
#         [ 82, 129, 194],
#         ...,
#         [ 53,  87, 135],
#         [ 53,  87, 134],
#         [ 53,  87, 134]],
#
#        [[ 75, 118, 183],
#         [ 77, 124, 185],
#         [ 83, 129, 194],
#         ...,
#         [ 52,  87, 134],
#         [ 52,  87, 135],
#         [ 52,  87, 136]]], dtype=uint8)

# %%
# Создание модели последовательной архитектуры
model = Sequential()

# %%
# Первый сверточный блок
model.add(Conv2D(256, (3, 3), name='First_C', padding='same', activation='relu', input_shape=(IMG_HEIGHT, IMG_WIDTH, 3)))  # (64,128,3) --> (64,128,256) меняется кол-во фильтров
model.add(BatchNormalization(name='First_B'))  # (64,128,256) --> (64,128,256) нет изменений
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Второй сверточный блок
model.add(Conv2D(256, (3, 3), name='Second_C', padding='same', activation='relu'))  # (64,128,256) --> (64,128,256) нет изменений
model.add(MaxPooling2D(pool_size=(3, 3), name='Second_M'))  # сжимает размер в три раза, с потерей, т.к. padding='valid', глубина не изм. (64,128,256) --> (21,42,256)

# %%
# Третий сверточный блок
model.add(Conv2D(256, (3, 3), name='Third_C', padding='same', activation='relu'))  # (21,42,256) --> (21,42,256) нет изменений
model.add(BatchNormalization(name='Third_B'))  # (21,42,256) --> (21,42,256) нет изменений
model.add(Dropout(0.2, name='Third_D'))  # (21,42,256) --> (21,42,256) нет изменений

# %%
# Четвертый сверточный блок
model.add(Conv2D(256, (3, 3), name='Fourth_F_Unique', padding='same', activation='relu'))  # (21,42,256) --> (21,42,256) нет изменений
model.add(MaxPooling2D(pool_size=(3, 3), name='Fourth_M_Unique'))  # сжимает размер в три раза, хотя padding='valid', потерь нет, т.к. делится кратно, глубина не изм. (21,42,256) --> (7,14,256)
model.add(Dropout(0.2, name='Fourth_D_Unique'))  # (7,14,256) --> (7,14,256) нет изменений

# %%
# Пятый сверточный блок
model.add(Conv2D(512, (3, 3), name='Fifth_D', padding='same', activation='relu'))  # (7,14,256) --> (7,14,512) меняется количество фильтров
model.add(BatchNormalization(name='Fifth_B'))  # (7,14,512) --> (7,14,512) нет изменений

# %%
# Шестой сверточный блок
model.add(Conv2D(1024, (3, 3), name='Sixth_C', padding='same', activation='relu'))  # (7,14,1024) --> (7,14,1024) меняется кол-во фильтров
model.add(MaxPooling2D(pool_size=(3, 3), name='Sixth_M'))  # сжимает размер в три раза, с потерей, т.к. padding='valid', глубина не изм. (7,14,1024) --> (2,4,1024)
model.add(Dropout(0.2, name='Sixth_D'))  # (2,4,1024) --> (2,4,1024) нет изменений

# %%
# Блок классификации
model.add(Flatten(name='Class_11'))  # слой преобразования многомерных данных в одномерные (2,4,1024) --> (2*4*1024) --> (8192)
model.add(Dense(2048, activation='relu', name='Class_12'))  # полносвязный слой, меняется кол-во нейронов (8192) --> (2048)
# model.add(Dense(4096, activation='relu', name='Class_3'))  # полносвязный слой, меняется кол-во нейронов (2048) --> (4096)
model.add(Dense(CLASS_COUNT, activation='softmax', name='Class_13'))  # выходной полносвязный слой, кол-во нейронов = количество классов (4096) --> (3)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ First_C (Conv2D)                │ (None, 64, 128, 256)   │         7,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ First_B (BatchNormalization)    │ (None, 64, 128, 256)   │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Second_C (Conv2D)               │ (None, 64, 128, 256)   │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Second_M (MaxPooling2D)         │ (None, 21, 42, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Third_C (Conv2D)                │ (None, 21, 42, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Third_B (BatchNormalization)    │ (None, 21, 42, 256)    │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Third_D (Dropout)               │ (None, 21, 42, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Fourth_F_Unique (Conv2D)        │ (None, 21, 42, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Fourth_M_Unique (MaxPooling2D)  │ (None, 7, 14, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Fourth_D_Unique (Dropout)       │ (None, 7, 14, 256)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Fifth_D (Conv2D)                │ (None, 7, 14, 512)     │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Fifth_B (BatchNormalization)    │ (None, 7, 14, 512)     │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Sixth_C (Conv2D)                │ (None, 7, 14, 1024)    │     4,719,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Sixth_M (MaxPooling2D)          │ (None, 2, 4, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Sixth_D (Dropout)               │ (None, 2, 4, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Class_11 (Flatten)              │ (None, 8192)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Class_12 (Dense)                │ (None, 2048)           │    16,779,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Class_13 (Dense)                │ (None, 3)              │         6,147 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 24,466,691 (93.33 MB)
#  Trainable params: 24,464,643 (93.33 MB)
#  Non-trainable params: 2,048 (8.00 KB)

# %%
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# Компиляция модели
model.compile(loss='sparse_categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])

# %%
# Разделение данных на обучающую и тестовую выборки
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=42)

# %%
# Определение колбэков
model_checkpoint = ModelCheckpoint(filepath='model_best.h5', monitor='val_loss', save_best_only=True, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.6, patience=2, verbose=1)

# %%
# Обучение модели и сохранение истории
history = model.fit(x_train,  # Обучающая выборка
                    y_train,  # Метки обучающей выборки
                    validation_data=(x_test, y_test),  # Тестовая выборка для валидации
                    shuffle=True,
                    batch_size=25,
                    epochs=30,
                    verbose=1,
                    callbacks=[model_checkpoint, reduce_lr])  # Добавление колбэков
# Out:
# Epoch 1/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.6128 - loss: 2.6244
# Epoch 1: val_loss improved from inf to 0.46954, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 62s 440ms/step - accuracy: 0.6139 - loss: 2.6085 - val_accuracy: 0.7950 - val_loss: 0.4695 - learning_rate: 1.0000e-04
# Epoch 2/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.8120 - loss: 0.3505
# Epoch 2: val_loss improved from 0.46954 to 0.36040, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 17s 184ms/step - accuracy: 0.8121 - loss: 0.3503 - val_accuracy: 0.8057 - val_loss: 0.3604 - learning_rate: 1.0000e-04
# Epoch 3/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.8361 - loss: 0.3198
# Epoch 3: val_loss improved from 0.36040 to 0.28267, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 17s 186ms/step - accuracy: 0.8362 - loss: 0.3195 - val_accuracy: 0.8699 - val_loss: 0.2827 - learning_rate: 1.0000e-04
# Epoch 4/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.8580 - loss: 0.2855
# Epoch 4: val_loss did not improve from 0.28267
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 16s 180ms/step - accuracy: 0.8581 - loss: 0.2854 - val_accuracy: 0.7611 - val_loss: 0.4273 - learning_rate: 1.0000e-04
# Epoch 5/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.8950 - loss: 0.2333
# Epoch 5: val_loss improved from 0.28267 to 0.20656, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 17s 194ms/step - accuracy: 0.8951 - loss: 0.2333 - val_accuracy: 0.9234 - val_loss: 0.2066 - learning_rate: 1.0000e-04
# Epoch 6/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9171 - loss: 0.1876
# Epoch 6: val_loss improved from 0.20656 to 0.18712, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 17s 190ms/step - accuracy: 0.9171 - loss: 0.1877 - val_accuracy: 0.9251 - val_loss: 0.1871 - learning_rate: 1.0000e-04
# Epoch 7/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9399 - loss: 0.1401
# Epoch 7: val_loss improved from 0.18712 to 0.15432, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 17s 189ms/step - accuracy: 0.9398 - loss: 0.1401 - val_accuracy: 0.9376 - val_loss: 0.1543 - learning_rate: 1.0000e-04
# Epoch 8/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9451 - loss: 0.1339
# Epoch 8: val_loss improved from 0.15432 to 0.14653, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 17s 188ms/step - accuracy: 0.9451 - loss: 0.1339 - val_accuracy: 0.9412 - val_loss: 0.1465 - learning_rate: 1.0000e-04
# Epoch 9/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9644 - loss: 0.0837
# Epoch 9: val_loss improved from 0.14653 to 0.14415, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 17s 188ms/step - accuracy: 0.9644 - loss: 0.0838 - val_accuracy: 0.9447 - val_loss: 0.1441 - learning_rate: 1.0000e-04
# Epoch 10/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9602 - loss: 0.1006
# Epoch 10: val_loss did not improve from 0.14415
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 16s 180ms/step - accuracy: 0.9601 - loss: 0.1009 - val_accuracy: 0.9287 - val_loss: 0.1600 - learning_rate: 1.0000e-04
# Epoch 11/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9679 - loss: 0.0883
# Epoch 11: val_loss improved from 0.14415 to 0.11279, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 17s 188ms/step - accuracy: 0.9680 - loss: 0.0880 - val_accuracy: 0.9519 - val_loss: 0.1128 - learning_rate: 1.0000e-04
# Epoch 12/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9858 - loss: 0.0426
# Epoch 12: val_loss did not improve from 0.11279
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.9857 - loss: 0.0428 - val_accuracy: 0.9269 - val_loss: 0.2339 - learning_rate: 1.0000e-04
# Epoch 13/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9697 - loss: 0.0701
# Epoch 13: val_loss did not improve from 0.11279
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 5.999999848427251e-05.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.9697 - loss: 0.0701 - val_accuracy: 0.9358 - val_loss: 0.1801 - learning_rate: 1.0000e-04
# Epoch 14/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9848 - loss: 0.0503
# Epoch 14: val_loss improved from 0.11279 to 0.05158, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 17s 188ms/step - accuracy: 0.9849 - loss: 0.0501 - val_accuracy: 0.9822 - val_loss: 0.0516 - learning_rate: 6.0000e-05
# Epoch 15/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9954 - loss: 0.0176
# Epoch 15: val_loss did not improve from 0.05158
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 16s 178ms/step - accuracy: 0.9954 - loss: 0.0177 - val_accuracy: 0.8449 - val_loss: 0.5026 - learning_rate: 6.0000e-05
# Epoch 16/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9932 - loss: 0.0204
# Epoch 16: val_loss did not improve from 0.05158
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 3.599999909056351e-05.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.9932 - loss: 0.0204 - val_accuracy: 0.9234 - val_loss: 0.1891 - learning_rate: 6.0000e-05
# Epoch 17/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9991 - loss: 0.0106
# Epoch 17: val_loss improved from 0.05158 to 0.04961, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 17s 189ms/step - accuracy: 0.9991 - loss: 0.0106 - val_accuracy: 0.9840 - val_loss: 0.0496 - learning_rate: 3.6000e-05
# Epoch 18/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9989 - loss: 0.0061
# Epoch 18: val_loss improved from 0.04961 to 0.03265, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 17s 188ms/step - accuracy: 0.9989 - loss: 0.0061 - val_accuracy: 0.9893 - val_loss: 0.0327 - learning_rate: 3.6000e-05
# Epoch 19/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9986 - loss: 0.0036
# Epoch 19: val_loss did not improve from 0.03265
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 16s 180ms/step - accuracy: 0.9986 - loss: 0.0036 - val_accuracy: 0.9697 - val_loss: 0.0688 - learning_rate: 3.6000e-05
# Epoch 20/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 20: val_loss improved from 0.03265 to 0.02823, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 17s 188ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9893 - val_loss: 0.0282 - learning_rate: 3.6000e-05
# Epoch 21/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9995 - loss: 0.0037
# Epoch 21: val_loss did not improve from 0.02823
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.9995 - loss: 0.0037 - val_accuracy: 0.9911 - val_loss: 0.0360 - learning_rate: 3.6000e-05
# Epoch 22/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9986 - loss: 0.0040
# Epoch 22: val_loss did not improve from 0.02823
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.1599998581223188e-05.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.9986 - loss: 0.0040 - val_accuracy: 0.9786 - val_loss: 0.0624 - learning_rate: 3.6000e-05
# Epoch 23/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9967 - loss: 0.0072
# Epoch 23: val_loss did not improve from 0.02823
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.9967 - loss: 0.0072 - val_accuracy: 0.9857 - val_loss: 0.0320 - learning_rate: 2.1600e-05
# Epoch 24/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9995 - loss: 0.0022
# Epoch 24: val_loss improved from 0.02823 to 0.02735, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 17s 189ms/step - accuracy: 0.9995 - loss: 0.0022 - val_accuracy: 0.9893 - val_loss: 0.0273 - learning_rate: 2.1600e-05
# Epoch 25/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 25: val_loss improved from 0.02735 to 0.02612, saving model to model_best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 17s 189ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9893 - val_loss: 0.0261 - learning_rate: 2.1600e-05
# Epoch 26/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 1.0000 - loss: 0.0018
# Epoch 26: val_loss did not improve from 0.02612
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.9893 - val_loss: 0.0297 - learning_rate: 2.1600e-05
# Epoch 27/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 27: val_loss did not improve from 0.02612
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.2959999367012642e-05.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 0.9893 - val_loss: 0.0272 - learning_rate: 2.1600e-05
# Epoch 28/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9982 - loss: 0.0030
# Epoch 28: val_loss did not improve from 0.02612
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 0.9982 - loss: 0.0030 - val_accuracy: 0.9929 - val_loss: 0.0296 - learning_rate: 1.2960e-05
# Epoch 29/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 1.0000 - loss: 6.3715e-04
# Epoch 29: val_loss did not improve from 0.02612
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 7.775999620207585e-06.
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 1.0000 - loss: 6.3842e-04 - val_accuracy: 0.9929 - val_loss: 0.0263 - learning_rate: 1.2960e-05
# Epoch 30/30
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 1.0000 - loss: 6.5178e-04
# Epoch 30: val_loss did not improve from 0.02612
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 16s 179ms/step - accuracy: 1.0000 - loss: 6.5268e-04 - val_accuracy: 0.9911 - val_loss: 0.0310 - learning_rate: 7.7760e-06

# %%
scores = model.evaluate(x_data,
                        y_data,
                        verbose=1
                        )
print('Процент верных ответов на тестовых данных:', round(scores[1],2) * 100, '%')
# Out:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 18s 128ms/step - accuracy: 0.9988 - loss: 0.0056
# Процент верных ответов на тестовых данных: 100.0 %

# %%
# Оценка модели на тестовой выборке
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=1)

print(f'Тестовая точность: {test_accuracy:.4f}')
print(f'Тестовая потеря: {test_loss:.4f}')
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.9893 - loss: 0.0337
# Тестовая точность: 0.9911
# Тестовая потеря: 0.0310

# %%
# Визуализация процесса обучения
plt.figure(figsize=(12, 4))

# График потерь
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Обучающие потери')
plt.plot(history.history['val_loss'], label='Валидационные потери')
plt.title('Потери модели')
plt.xlabel('Эпохи')
plt.ylabel('Потери')
plt.legend()

# График точности
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Обучающая точность')
plt.plot(history.history['val_accuracy'], label='Валидационная точность')
plt.title('Точность модели')
plt.xlabel('Эпохи')
plt.ylabel('Точность')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Получение предсказаний
predictions = model.predict(x_test)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step

# %%
# Определение класса с максимальной вероятностью для каждого изображения
predicted_classes = np.argmax(predictions, axis=1)

# %%
# Выбор одного изображения из каждого класса
unique_classes = np.unique(predicted_classes)
images_per_class = []
for cls in unique_classes:
    class_indices = np.where(predicted_classes == cls)[0]
    if len(class_indices) > 0:
        images_per_class.append(x_test[class_indices[0]])

# %%
# После завершения обучения модели
model.save('my_model.keras')
